# %% [markdown]
# # Combine Central Node data of each day, average per 10 min and make a single dataFrame

# %%
using CSV
using DataFrames
using Dates
using Statistics
using Plots

# %%
# Local machine path to raw data
path = "/Users/prabu/Desktop/Dounload_Central_data/JoppaCentralRawData/raw/001e0636e547"

nodeId = "001e0636e547";

# %%
years_path = filter(isdir,readdir(path,join=true)) 
years = basename.(years_path);

# %%
sensorName = ["BME280","IPS7100"];

# %%
function ss(dirr, csvv, sensr)
    df = CSV.read(dirr, DataFrame)
    
    try
    	df.dateTime =  SubString.(string.(df.dateTime), 1, 19) 
    	df.dateTime = DateTime.(df.dateTime,"yyyy-mm-dd HH:MM:SS")  
        #println(df)
    	df.dateTime = map((x) -> round(x, Dates.Minute(10)), df.dateTime)  
    	gdf = groupby(df, :dateTime)  
    	cgdf = combine(gdf, valuecols(gdf) .=> mean)
    
    	colFullName = names(cgdf)
    	for x in 2:length(colFullName)                                      # Starting from 2nd column and go through all the columns           
            num_let = length(colFullName[x])                                # taking number of characters in one column name
            colName = SubString.(string.(colFullName[x]), 1, num_let-5)     # removing last five characters of each column name (that is _mean)
            rename!(cgdf,colFullName[x] => sensr*"_"*colName)               # adding sensor name to the column name
    	end
    	return cgdf  
    	
    catch e println("Error on "*csvv) end

end;

# %%
n = 0
for sensor in sensorName
    k = 0
    for y in years
        months = readdir(path*"/"*y)
        for m in months
            try days = readdir(path*"/"*y*"/"*m)
                for d in days
                    try filess = readdir(path*"/"*y*"/"*m*"/"*d)
                        CSV_file = "MINTS_"*nodeId*"_"*sensor*"_"*y*"_"*m*"_"*d*".csv"
                        
                        if (CSV_file in filess)
                            dir = path*"/"*y*"/"*m*"/"*d*"/"*CSV_file
                            averaged_df = ss(dir, CSV_file, sensor)
                            df2 = averaged_df
                            k = k + 1
                            if (k > 1) global new_df = outerjoin(new_df, df2, on = intersect(names(new_df), names(df2)))
                            else new_df = averaged_df end
                        else println("No data of "*sensor) end
                        
                    catch e println("error on "*d) end
                end
            catch e println("error on "*m) end
        end
    end

    global n = n + 1
    if (n > 1) global final_df = outerjoin(final_df, new_df, on = :dateTime, makeunique=true) 
    else final_df = new_df end
end
# Out:
# ┌ Warning: thread = 1 warning: parsed expected 15 columns, but didn't reach end of line around data row: 72517. Parsing extra columns and widening final columnset
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:579
# ┌ Warning: thread = 1 warning: parsed expected 15 columns, but didn't reach end of line around data row: 72517. Parsing extra columns and widening final columnset
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:579
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72518. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72519. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72520. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72521. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72522. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72523. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72524. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72525. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72526. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72527. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72528. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72529. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72530. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72531. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72532. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72533. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72534. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72535. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72536. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72537. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72538. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72539. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72540. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72541. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72542. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72543. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72544. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72545. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72546. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72547. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72548. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72549. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72550. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72551. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72552. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72553. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72554. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72555. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72556. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72557. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72558. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72559. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72560. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72561. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72562. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72563. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72564. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72565. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72566. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72567. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72568. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72569. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72570. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72571. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72572. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72573. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72574. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72575. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72576. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72577. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72578. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72579. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72580. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72581. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72582. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72583. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72584. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72585. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72586. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72587. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72588. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72589. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72590. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72591. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72592. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72593. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72594. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72595. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72596. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72597. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72598. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72599. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72600. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72601. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72602. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72603. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 72604. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 1. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 2. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 3. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 4. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 5. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 6. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 7. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 8. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 9. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 10. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 11. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 12. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 13. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 28 columns around data row: 14. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1: too many warnings, silencing any further warnings
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:583
# ┌ Warning: thread = 1 warning: parsed expected 15 columns, but didn't reach end of line around data row: 72868. Parsing extra columns and widening final columnset
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:579
# ┌ Warning: thread = 1 warning: parsed expected 15 columns, but didn't reach end of line around data row: 72868. Parsing extra columns and widening final columnset
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:579
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72869. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72870. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72871. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72872. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72873. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72874. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72875. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72876. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72877. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72878. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72879. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72880. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72881. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72882. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72883. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72884. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72885. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72886. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72887. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72888. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72889. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72890. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72891. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72892. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72893. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72894. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72895. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72896. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72897. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72898. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72899. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72900. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72901. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72902. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72903. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72904. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72905. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72906. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72907. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72908. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72909. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72910. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72911. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72912. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72913. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72914. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72915. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72916. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72917. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72918. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72919. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72920. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72921. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72922. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72923. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72924. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72925. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72926. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72927. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72928. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72929. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72930. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72931. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72932. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72933. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72934. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72935. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72936. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72937. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72938. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72939. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72940. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72941. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72942. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72943. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72944. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72945. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72946. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72947. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72948. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72949. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72950. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72951. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72952. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72953. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72954. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72955. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72956. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72957. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72958. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72959. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72960. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72961. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72962. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72963. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72964. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72965. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72966. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72967. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72968. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 23 columns around data row: 72969. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1: too many warnings, silencing any further warnings
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:583
# ┌ Warning: thread = 1 warning: parsed expected 15 columns, but didn't reach end of line around data row: 37982. Parsing extra columns and widening final columnset
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:579
# ┌ Warning: thread = 1 warning: parsed expected 15 columns, but didn't reach end of line around data row: 37982. Parsing extra columns and widening final columnset
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:579
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 37983. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 37984. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 37985. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 37986. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 37987. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 37988. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 37989. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 37990. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 37991. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 37992. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 37993. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 37994. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 37995. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 37996. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 37997. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 37998. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 37999. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 38000. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 38001. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 38002. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 38003. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 38004. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 38005. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 38006. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 38007. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 38008. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 38009. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 38010. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 38011. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 38012. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 38013. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 38014. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 38015. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 38016. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 38017. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 38018. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 38019. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 38020. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 38021. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 38022. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 38023. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 38024. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 38025. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 38026. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 38027. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 38028. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 17 columns around data row: 38029. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ...
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47525. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47526. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47527. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47528. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47529. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47530. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47531. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47532. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47533. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47534. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47535. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47536. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47537. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47538. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47539. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47540. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47541. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47542. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47543. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47544. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47545. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47546. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47547. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47548. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47549. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47550. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47551. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47552. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47553. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47554. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47555. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47556. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47557. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47558. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47559. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47560. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47561. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47562. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47563. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47564. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47565. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47566. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47567. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# error on .DS_Store
# error on .DS_Store
# Error on MINTS_001e0636e547_BME280_2022_04_25.csv
# error on 25
# error on .DS_Store
# error on .DS_Store
# Error on MINTS_001e0636e547_BME280_2022_06_11.csv
# error on 11
# No data of BME280
# No data of BME280
# No data of BME280
# No data of BME280
# No data of BME280
# No data of BME280
# No data of BME280
# No data of BME280
# error on .DS_Store
# error on .DS_Store
# Error on MINTS_001e0636e547_IPS7100_2022_04_25.csv
# error on 25
# error on .DS_Store
# Error on MINTS_001e0636e547_IPS7100_2022_05_03.csv
# error on 03
# error on .DS_Store
# Error on MINTS_001e0636e547_IPS7100_2022_06_02.csv
# error on 02
# Error on MINTS_001e0636e547_IPS7100_2022_06_11.csv
# error on 11
# error on .DS_Store
# Error on MINTS_001e0636e547_IPS7100_2022_07_08.csv
# error on 08
# No data of IPS7100
# No data of IPS7100
# No data of IPS7100
# No data of IPS7100
# No data of IPS7100
# No data of IPS7100
# No data of IPS7100
# No data of IPS7100
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47568. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47569. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47570. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47571. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47572. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47573. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47574. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47575. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47576. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47577. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47578. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47579. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47580. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47581. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47582. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47583. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47584. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47585. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47586. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47587. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47588. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47589. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47590. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47591. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47592. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47593. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47594. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47595. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47596. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47597. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47598. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47599. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47600. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47601. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47602. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47603. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 15 / 26 columns around data row: 47604. Filling remaining columns with `missing`
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1: too many warnings, silencing any further warnings
# └ @ CSV /Users/prabu/.julia/packages/CSV/jFiCn/src/file.jl:583

# %%
final_df2 = sort!(final_df)

select!(final_df2, Not([:IPS7100_pc0_1, :IPS7100_pc0_3, :IPS7100_pc0_5, :IPS7100_pc1_0, :IPS7100_pc2_5, :IPS7100_pc5_0, 
            :IPS7100_pc10_0]))

for col in names(final_df2)
    if nrow(final_df2) == sum(ismissing.(final_df2[!, col])) select!(final_df2, Not(col)) end
end

CSV.write("/Users/prabu/Desktop/Joppa/df_central_new.csv", final_df2)
# Out:
# "/Users/prabu/Desktop/Joppa/df_central_new.csv"
